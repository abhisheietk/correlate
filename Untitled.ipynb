# %%
import numpy as np

master = np.genfromtxt(
    'master0.csv',           # file name
    skip_header=5,          # lines to skip at the top
    skip_footer=0,          # lines to skip at the bottom
    delimiter=',',          # column delimiter
    dtype='float64',        # data type
    filling_values=0,       # fill missing values with 0
    usecols = (0,1),    # columns to read
    names=['Time', ',Ampl'])     # column names
slave = np.genfromtxt(
    'slave0.csv',           # file name
    skip_header=5,          # lines to skip at the top
    skip_footer=0,          # lines to skip at the bottom
    delimiter=',',          # column delimiter
    dtype='float32',        # data type
    filling_values=0,       # fill missing values with 0
    usecols = (0,1),    # columns to read
    names=['Time', 'Ampl'])     # column names

# %%
#correlation = np.correlate(master['Ampl'], slave['Ampl'], "full")

# %%
#print (correlation)

# %%
a = master['Ampl']
b = slave['Ampl']
print(len(a), len(b))
print(np.corrcoef(a, b))
# Out:
# 400002 400002
# [[ 1.         -0.24911718]
#  [-0.24911718  1.        ]]

# %%
print(a[20000:20100])
# Out:
# [ 0.0148669   0.0123578   0.0106648   0.0107789   0.0125555   0.0148443
#   0.0162256   0.015862    0.0139646   0.0116639   0.0103569   0.0108731
#   0.0129536   0.0154215   0.0168837   0.0165109   0.0144861   0.0119345
#   0.010341    0.0106847   0.0128063   0.015456    0.0170681   0.0167033
#   0.0145657   0.011851    0.0100756   0.0102282   0.0121906   0.0148311
#   0.0166714   0.0166966   0.0148961   0.0122875   0.010402    0.0104007
#   0.0123565   0.0151694   0.0172274   0.0173388   0.0153963   0.0124361
#   0.0100716   0.00957143  0.0111318   0.0138081   0.0160863   0.0167271
#   0.0154149   0.0129098   0.0106568   0.0099854   0.0113215   0.0139036
#   0.0162362   0.0169925   0.0157678   0.0132747   0.0109261   0.0100504
#   0.0111544   0.0136475   0.0161592   0.0172857   0.0163822   0.0139567
#   0.0114012   0.010199    0.0110363   0.0134007   0.0159071   0.0171053
#   0.0162999   0.0139354   0.0113667   0.0100716   0.0107722   0.0130106
# ...

# %%
#correlation = np.correlate(a, b[0:100], "full")
def correlate(a, b, windowsize = 1000, offset = 10000):
    correlation = []
    for i in range(len(a)-windowsize):
        print( a[i: windowsize+i], offset, b[offset+windowsize])
        c = a[0+i:windowsize+i] - b[offset:offset+windowsize]
        correlation.append(1/c.var())
    return correlation
#print(correlation)

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import animation

fig = plt.figure()
line, = ax.plot([], [])

# initialization function: plot the background of each frame
def init():
    line.set_data([], [])
    return line,

# animation function.  This is called sequentially
def animate(i):
    correlation = correlate(a, b[0:100], windowsize = 1000, offset = 0+i*1000)
    x = np.arange(0, len(correlation))
    y = correlation
    line.set_data(x, y)
    return line,

# call the animator.  blit=True means only re-draw the parts that have changed.
anim = animation.FuncAnimation(fig, animate, init_func=init,
                               frames=1000, interval=20, blit=True)
writer = animation.writers['ffmpeg'](fps=30)
anim.save('demo.mp4',writer=writer,dpi=dpi)
# call our new function to display the animation
#display_animation(anim)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-ddc8491252b5> in <module>()
#       5
#       6 fig = plt.figure()
# ----> 7 line, = ax.plot([], [])
#       8
#       9 # initialization function: plot the background of each frame
#
# NameError: name 'ax' is not defined

# %%
import matplotlib.animation as animation
import numpy as np
from pylab import *


dpi = 100

def ani_frame():
    fig = plt.figure()
    ax = fig.add_subplot(111)
    ax.set_aspect('equal')
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    im = ax.imshow(rand(300,300),cmap='gray',interpolation='nearest')
    im.set_clim([0,1])
    fig.set_size_inches([5,5])


    tight_layout()


    def update_img(n):
        tmp = rand(300,300)
        im.set_data(tmp)
        return im

    #legend(loc=0)
    ani = animation.FuncAnimation(fig,update_img,300,interval=30)
    writer = animation.writers['ffmpeg'](fps=30)

    ani.save('demo.mp4',writer=writer,dpi=dpi)
    return ani

# %%
# %matplotlib inline
ani_frame()

# %%
# First set up the figure, the axis, and the plot element we want to animate
fig = plt.figure()
ax = plt.axes(xlim=(0, 2), ylim=(-2, 2))
line, = ax.plot([], [], lw=2)

# initialization function: plot the background of each frame
def init():
    line.set_data([], [])
    return line,

# animation function.  This is called sequentially
def animate(i):
    x = np.linspace(0, 2, 1000)
    y = np.sin(2 * np.pi * (x - 0.01 * i))
    line.set_data(x, y)
    return line,

# call the animator.  blit=True means only re-draw the parts that have changed.
anim = animation.FuncAnimation(fig, animate, init_func=init,
                               frames=100, interval=20, blit=True)

# call our new function to display the animation
display_animation(anim)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-4e4f44746e28> in <module>()
#      21
#      22 # call our new function to display the animation
# ---> 23 display_animation(anim)
#      24
#
# NameError: name 'display_animation' is not defined

# %%
# %pylab inline
from tempfile import NamedTemporaryFile

VIDEO_TAG = """<video controls>
 <source src="data:video/x-m4v;base64,{0}" type="video/mp4">
 Your browser does not support the video tag.
</video>"""

def anim_to_html(anim):
    if not hasattr(anim, '_encoded_video'):
        with NamedTemporaryFile(suffix='.mp4') as f:
            anim.save(f.name, fps=20, extra_args=['-vcodec', 'libx264'])
            video = open(f.name, "rb").read()
        anim._encoded_video = video.encode("base64")
    
    return VIDEO_TAG.format(anim._encoded_video)

from IPython.display import HTML

def display_animation(anim):
    plt.close(anim._fig)
    return HTML(anim_to_html(anim))
from matplotlib import animation

# First set up the figure, the axis, and the plot element we want to animate
fig = plt.figure()
ax = plt.axes(xlim=(0, 2), ylim=(-2, 2))
line, = ax.plot([], [], lw=2)

# initialization function: plot the background of each frame
def init():
    line.set_data([], [])
    return line,

# animation function.  This is called sequentially
def animate(i):
    x = np.linspace(0, 2, 1000)
    y = np.sin(2 * np.pi * (x - 0.01 * i))
    line.set_data(x, y)
    return line,

# call the animator.  blit=True means only re-draw the parts that have changed.
anim = animation.FuncAnimation(fig, animate, init_func=init,
                               frames=100, interval=20, blit=True)

# call our new function to display the animation
display_animation(anim)
# Out:
# Populating the interactive namespace from numpy and matplotlib
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-a7ba73de7c38> in <module>()
#      45
#      46 # call our new function to display the animation
# ---> 47 display_animation(anim)
#
# <ipython-input-10-a7ba73de7c38> in display_animation(anim)
#      20 def display_animation(anim):
#      21     plt.close(anim._fig)
# ---> 22     return HTML(anim_to_html(anim))
#      23 from matplotlib import animation
#      24
#
# <ipython-input-10-a7ba73de7c38> in anim_to_html(anim)
#      12             anim.save(f.name, fps=20, extra_args=['-vcodec', 'libx264'])
#      13             video = open(f.name, "rb").read()
# ---> 14         anim._encoded_video = video.encode("base64")
#      15
#      16     return VIDEO_TAG.format(anim._encoded_video)
#
# AttributeError: 'bytes' object has no attribute 'encode'

# %%
import moviepy.editor as mpy

# %%
mpy.ipython_display("")
