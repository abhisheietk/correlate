# %%
import numpy as np
master = np.genfromtxt(
    'master.csv',           # file name
    skip_header=5,          # lines to skip at the top
    skip_footer=0,          # lines to skip at the bottom
    delimiter=',',          # column delimiter
    dtype='float64',        # data type
    filling_values=0,       # fill missing values with 0
    usecols = (0,1),    # columns to read
    names=['Time', ',Ampl'])     # column names
slave = np.genfromtxt(
    'slave.csv',           # file name
    skip_header=5,          # lines to skip at the top
    skip_footer=0,          # lines to skip at the bottom
    delimiter=',',          # column delimiter
    dtype='float32',        # data type
    filling_values=0,       # fill missing values with 0
    usecols = (0,1),    # columns to read
    names=['Time', 'Ampl'])     # column names

# %%
import matplotlib.pyplot as plt
print(len(master))
x = 250
plt.plot(master['Ampl'][300:1000], slave['Ampl'][300+x:1000+x])
plot.sc
#plt.plot(slave['Ampl'][300+x:10000+x])#, slave['Ampl'][0+x:1000+x])
#plt.plot()
plt.ylabel('some numbers')
plt.show()
# Out:
# 400002

# %%
print(master)
# Out:
# [(-5.0000106e-06, 0.0169766) (-4.9999856e-06, 0.0151071)
#  (-4.9999606e-06, 0.0122105) ..., (4.9999644e-06, 0.0161685)
#  (4.9999894e-06, 0.0170111) (5.0000144e-06, 0.015858)]
